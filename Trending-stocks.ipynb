# %%
import quantstats as qs
import yfinance as yf
# %matplotlib inline

# %%
qs.extend_pandas()

stock = qs.utils.download_returns('GOOG')

qs.stats.sharpe(stock)

stock.sharpe()
# Out:
# 0.9048766336894882

# %%
#extend pandas functionality with metrics, etc.
qs.extend_pandas()

#fetch the daily returns for a stock
stock = qs.utils.download_returns('FB')

#show sharpe ratio
qs.stats.sharpe(stock)

# or using extend_pandas
stock.sharpe()
# Out:
# 0.6631767480246626

# %%
qs.extend_pandas()

stock = qs.utils.download_returns('AMZN')

qs.stats.sharpe(stock)

stock.sharpe()
# Out:
# 0.799584765541547

# %%
qs.extend_pandas()

stock = qs.utils.download_returns('MSFT')

qs.stats.sharpe(stock)

stock.sharpe()
# Out:
# 0.8676448839490449

# %%
qs.extend_pandas()

stock = qs.utils.download_returns('AAPL')

qs.stats.sharpe(stock)

stock.sharpe()
# Out:
# 0.6295440000456389

# %%
qs.plots.snapshot(stock, title= "GOOG")

# %%
qs.plots.snapshot(stock, title= "AMZN")

# %%
qs.plots.snapshot(stock, title= "MSFT")

# %%
qs.plots.snapshot(stock, title= "FB")

# %%
qs.plots.snapshot(stock, title= "AAPL")
