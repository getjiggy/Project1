# %%
import quantstats as qs
import yfinance as yf
import pandas as pd
# %matplotlib inline

# %%
qs.extend_pandas()

GOOG_api = qs.utils.download_returns('GOOG')

qs.stats.sharpe(GOOG_api)

GOOG_api.sharpe()
# Out:
# 0.9048766336894882

# %%
#extend pandas functionality with metrics, etc.
qs.extend_pandas()

#fetch the daily returns for a stock
FB_api = qs.utils.download_returns('FB')

#show sharpe ratio
qs.stats.sharpe(FB_api)

# or using extend_pandas
FB_api.sharpe()
# Out:
# 0.6631767480246626

# %%
qs.extend_pandas()

AMZN_api = qs.utils.download_returns('AMZN')

qs.stats.sharpe(AMZN_api)

AMZN_api.sharpe()
# Out:
# 0.799584765541547

# %%
qs.extend_pandas()

MSFT_api = qs.utils.download_returns('MSFT')

qs.stats.sharpe(MSFT_api)

MSFT_api.sharpe()
# Out:
# 0.8676449066757489

# %%
qs.extend_pandas()

AAPL_api = qs.utils.download_returns('AAPL')

qs.stats.sharpe(AAPL_api)

AAPL_api.sharpe()
# Out:
# 0.6295440125285496

# %%
print()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10128/2356412119.py in <module>
# ----> 1 print(GOOG)
#
# NameError: name 'GOOG' is not defined

# %%
GOOG_api = qs.plots.snapshot(GOOG_api, title= "GOOG")

# %%
AMZN_api = qs.plots.snapshot(AMZN_api, title= "AMZN")

# %%
MSFT_api = qs.plots.snapshot(MSFT_api, title= "MSFT")

# %%
FB_api = qs.plots.snapshot(FB_api, title= "Facebook Peformance")

# %%
AAPL_api = qs.plots.snapshot(AAPL_ap, title= "AAPL")
