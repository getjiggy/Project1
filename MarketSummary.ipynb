# %%
# Import libraries and dependencies
import quantstats as qs
import yfinance as yf
import numpy as np
import pandas as pd
import hvplot.pandas
import os

# extend pandas functionality with metrics, etc.
qs.extend_pandas()

# Load .env enviroment variables
from dotenv import load_dotenv
load_dotenv()

# %matplotlib inline

# %%
# Insuring code works & practice
# extend pandas functionality with metrics, etc.
qs.extend_pandas()

# fetch the daily returns for a stock
spy_daily_returns = qs.utils.download_returns("SNP")

# %%
# Insuring code works & practice
# show sharpe ratio
qs.stats.sharpe(spy_daily_returns)

# or using extend_pandas()
spy_daily_returns.sharpe()
# Out:
# 0.4697138242667492

# %%
spy_daily_returns
# Out:
# Date
# 2000-10-18         NaN
# 2000-10-19   -0.027108
# 2000-10-20   -0.009288
# 2000-10-23   -0.031250
# 2000-10-24   -0.032258
#                 ...
# 2022-02-07    0.007856
# 2022-02-08   -0.002227
# 2022-02-09    0.008185
# 2022-02-10   -0.002768
# 2022-02-11    0.017946
# Name: Close, Length: 5364, dtype: float64

# %%
qs.plots.snapshot(spy_daily_returns, title='Performance')

# can also be called via:
# stock.plot_snapshot(title='Facebook Performance')

# %%
qs.reports.full(spy_daily_returns, "SPY")
# Out:
# <h4>Performance Metrics</h4>
#                            Strategy    Benchmark
# -------------------------  ----------  -----------
# Start Period               2000-10-18  2000-10-18
# End Period                 2022-02-11  2022-02-11
# Risk-Free Rate             0.0%        0.0%
# Time in Market             100.0%      100.0%
#
# Cumulative Return          864.49%     389.03%
# CAGR﹪                     11.21%      7.72%
#
# Sharpe                     0.47        0.48
# Smart Sharpe               0.43        0.44
# Sortino                    0.7         0.68
# Smart Sortino              0.65        0.62
# Sortino/√2                 0.5         0.48
# Smart Sortino/√2           0.46        0.44
# Omega                      1.09        1.09
#
# Max Drawdown               -73.1%      -55.19%
# Longest DD Days            3827        2005
# Volatility (ann.)          37.73%      19.48%
# R^2                        0.28        0.28
# Calmar                     0.15        0.14
# ...

# %%
df = yf.download(" DJI SNP NIM", period = "5y")
# Out:
# [*********************100%***********************]  3 of 3 completed

# %%
df
# Out:
#                Adj Close                               Close         \
#                      DJI        NIM        SNP           DJI    NIM
# Date
# 2017-02-13  20412.199219   8.374485  54.023056  20412.199219   9.78
# 2017-02-14  20504.400391   8.365919  53.598316  20504.400391   9.77
# 2017-02-15  20611.900391   8.391609  53.139866  20611.900391   9.80
# 2017-02-16  20619.800781   8.391609  52.243187  20619.800781   9.80
# 2017-02-17  20624.099609   8.400177  52.620747  20624.099609   9.81
# ...                  ...        ...        ...           ...    ...
# 2022-02-07  35091.101562  10.030000  53.880001  35091.101562  10.03
# 2022-02-08  35462.800781   9.960000  53.759998  35462.800781   9.96
# 2022-02-09  35768.101562  10.050000  54.200001  35768.101562  10.05
# 2022-02-10  35241.601562  10.020000  54.049999  35241.601562  10.02
# 2022-02-11           NaN  10.040000  55.020000           NaN  10.04
#
# ...

# %%
# Set timeframe to '1D'
timeframe = "5Y"

# Set start and end datetimes of 5 years from Today
start_date = pd.Timestamp("2017-02-01", tz="America/New_York").isoformat()
end_date = pd.Timestamp("2022-02-01", tz="America/New_York").isoformat()

# Set the stock tickers
tickers = ["DJI", "SNP", "NIM"]

df.head()
# Out:
#                     Open          High           Low         Close     Volume
# Date
# 2017-02-13  20412.199219  20412.199219  20412.199219  20412.199219  281140828
# 2017-02-14  20504.400391  20504.400391  20504.400391  20504.400391  316608894
# 2017-02-15  20611.900391  20611.900391  20611.900391  20611.900391  340722690
# 2017-02-16  20619.800781  20619.800781  20619.800781  20619.800781  321136086
# 2017-02-17  20624.099609  20624.099609  20624.099609  20624.099609  281171106

# %%
df
# Out:
#                     Open          High           Low         Close     Volume
# Date
# 2017-02-13  20412.199219  20412.199219  20412.199219  20412.199219  281140828
# 2017-02-14  20504.400391  20504.400391  20504.400391  20504.400391  316608894
# 2017-02-15  20611.900391  20611.900391  20611.900391  20611.900391  340722690
# 2017-02-16  20619.800781  20619.800781  20619.800781  20619.800781  321136086
# 2017-02-17  20624.099609  20624.099609  20624.099609  20624.099609  281171106
# ...                  ...           ...           ...           ...        ...
# 2022-02-04  35089.699219  35089.699219  35089.699219  35089.699219          0
# 2022-02-07  35091.101562  35091.101562  35091.101562  35091.101562          0
# 2022-02-08  35462.800781  35462.800781  35462.800781  35462.800781          0
# 2022-02-09  35768.101562  35768.101562  35768.101562  35768.101562          0
# 2022-02-10  35241.601562  35241.601562  35241.601562  35241.601562          0
#
# [1087 rows x 5 columns]

# %%
qs.extend_pandas()

dji_daily_returns = qs.utils.download_returns("DJI")

# %%
# show sharpe ratio
qs.stats.sharpe(df_daily_returns)

# or using extend_pandas()
dji_daily_returns.sharpe()
# Out:
# 0.5119377021885492

# %%
dji_daily_returns
# Out:
# Date
# 1970-01-02         NaN
# 1970-01-05    0.002607
# 1970-01-06   -0.009429
# 1970-01-07   -0.002302
# 1970-01-08    0.000324
#                 ...
# 2022-02-04   -0.000612
# 2022-02-07    0.000040
# 2022-02-08    0.010592
# 2022-02-09    0.008609
# 2022-02-10   -0.014720
# Name: Close, Length: 12974, dtype: float64

# %%
qs.plots.snapshot(dji_daily_returns, title='Dow Jones Industrial Average Performance')

# can also be called via:
# stock.plot_snapshot(title='Facebook Performance')

# %%
qs.reports.full(dji_daily_returns, "DJI")
# Out:
# <h4>Performance Metrics</h4>
#                            Strategy    Benchmark
# -------------------------  ----------  -----------
# Start Period               1970-01-02  1970-01-02
# End Period                 2022-02-10  2022-02-10
# Risk-Free Rate             0.0%        0.0%
# Time in Market             100.0%      100.0%
#
# Cumulative Return          4,255.12%   4,243.79%
# CAGR﹪                     7.51%       7.5%
#
# Sharpe                     0.51        0.51
# Smart Sharpe               0.5         0.5
# Sortino                    0.73        0.73
# Smart Sortino              0.71        0.71
# Sortino/√2                 0.51        0.51
# Smart Sortino/√2           0.5         0.5
# Omega                      1.1         1.1
#
# Max Drawdown               -53.78%     -53.78%
# Longest DD Days            3582        3582
# Volatility (ann.)          17.24%      17.24%
# R^2                        1.0         1.0
# Calmar                     0.14        0.14
# ...

# %%
# Set timeframe to '1D'
timeframe = "5Y"

# Set start and end datetimes of 5 years from Today
start_date = pd.Timestamp("2017-02-01", tz="America/New_York").isoformat()
end_date = pd.Timestamp("2022-02-01", tz="America/New_York").isoformat()

# Set the stock tickers
tickers = ["DJI", "SNP", "NIM"]

df.head()
# Out:
#                     Open          High           Low         Close     Volume
# Date
# 2017-02-13  20412.199219  20412.199219  20412.199219  20412.199219  281140828
# 2017-02-14  20504.400391  20504.400391  20504.400391  20504.400391  316608894
# 2017-02-15  20611.900391  20611.900391  20611.900391  20611.900391  340722690
# 2017-02-16  20619.800781  20619.800781  20619.800781  20619.800781  321136086
# 2017-02-17  20624.099609  20624.099609  20624.099609  20624.099609  281171106

# %%
qs.extend_pandas()

snp_daily_returns = qs.utils.download_returns("SNP")

# %%
# show sharpe ratio
qs.stats.sharpe(snp_daily_returns)

# or using extend_pandas()
snp_daily_returns.sharpe()
# Out:
# 0.4697137940350029

# %%
snp_daily_returns
# Out:
# Date
# 2000-10-18         NaN
# 2000-10-19   -0.027108
# 2000-10-20   -0.009288
# 2000-10-23   -0.031250
# 2000-10-24   -0.032258
#                 ...
# 2022-02-07    0.007856
# 2022-02-08   -0.002227
# 2022-02-09    0.008185
# 2022-02-10   -0.002768
# 2022-02-11    0.017946
# Name: Close, Length: 5364, dtype: float64

# %%
qs.plots.snapshot(snp_daily_returns, title='S&NP 500 Performance')

# can also be called via:
# stock.plot_snapshot(title='Facebook Performance')

# %%
qs.reports.full(snp_daily_returns, "DJI")
# Out:
# <h4>Performance Metrics</h4>
#                            Strategy    Benchmark
# -------------------------  ----------  -----------
# Start Period               2000-10-18  2000-10-18
# End Period                 2022-02-11  2022-02-11
# Risk-Free Rate             0.0%        0.0%
# Time in Market             100.0%      97.0%
#
# Cumulative Return          864.49%     253.3%
# CAGR﹪                     11.21%      6.1%
#
# Sharpe                     0.47        0.41
# Smart Sharpe               0.43        0.38
# Sortino                    0.7         0.58
# Smart Sortino              0.65        0.54
# Sortino/√2                 0.5         0.41
# Smart Sortino/√2           0.46        0.38
# Omega                      1.09        1.09
#
# Max Drawdown               -73.1%      -53.78%
# Longest DD Days            3827        1973
# Volatility (ann.)          37.73%      18.82%
# R^2                        0.25        0.25
# Calmar                     0.15        0.11
# ...

# %%
qs.extend_pandas()

nim_daily_returns = qs.utils.download_returns("NIM")

# %%
# show sharpe ratio
qs.stats.sharpe(nim_daily_returns)

# or using extend_pandas()
nim_daily_returns.sharpe()
# Out:
# 0.33191718070734183

# %%
nim_daily_returns
# Out:
# Date
# 1992-09-21         NaN
# 1992-09-22    0.000000
# 1992-09-23    0.000000
# 1992-09-24    0.000000
# 1992-09-25    0.000000
#                 ...
# 2022-02-07    0.004004
# 2022-02-08   -0.006979
# 2022-02-09    0.009036
# 2022-02-10   -0.002985
# 2022-02-11    0.001996
# Name: Close, Length: 7405, dtype: float64

# %%
qs.plots.snapshot(nim_daily_returns, title='Net Interest Margin Performance')

# can also be called via:
# stock.plot_snapshot(title='Facebook Performance')

# %%
qs.reports.full(nim_daily_returns, "NIM")
# Out:
# <h4>Performance Metrics</h4>
#                            Strategy    Benchmark
# -------------------------  ----------  -----------
# Start Period               1992-09-21  1992-09-21
# End Period                 2022-02-11  2022-02-11
# Risk-Free Rate             0.0%        0.0%
# Time in Market             85.0%       85.0%
#
# Cumulative Return          196.0%      196.0%
# CAGR﹪                     3.76%       3.76%
#
# Sharpe                     0.33        0.33
# Smart Sharpe               0.28        0.28
# Sortino                    0.48        0.48
# Smart Sortino              0.4         0.4
# Sortino/√2                 0.34        0.34
# Smart Sortino/√2           0.28        0.28
# Omega                      1.06        1.06
#
# Max Drawdown               -18.91%     -18.91%
# Longest DD Days            1198        1198
# Volatility (ann.)          14.13%      14.13%
# R^2                        1.0         1.0
# Calmar                     0.2         0.2
# ...

# %%
# Set timeframe to '1D'
timeframe = "5Y"

# Set start and end datetimes of 5 years from Today
start_date = pd.Timestamp("2017-02-01", tz="America/New_York").isoformat()
end_date = pd.Timestamp("2022-02-01", tz="America/New_York").isoformat()

# Set the stock tickers
tickers = ["DJI", "SNP", "NIM"]

# Display sample data
df_ticker.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_25872/887131003.py in <module>
#      10
#      11 # Display sample data
# ---> 12 df_ticker.head()
#
# NameError: name 'df_ticker' is not defined

# %%
# Concatenate the two DataFrames by columns and perform an inner join
combnined_stock = pd.concat([dji_daily_returns, snp_daily_returns, nim_daily_returns], axis="columns", join="inner")

# Sort datetime index in ascending order (past to present)
combnined_stock.sort_index(inplace=True)

# Display a few rows
combnined_stock.head()
# Out:
#                Close     Close     Close
# Date
# 2000-10-18 -0.011366       NaN  0.000000
# 2000-10-19  0.016840 -0.027108 -0.006173
# 2000-10-20  0.008242 -0.009288  0.012422
# 2000-10-23  0.004410 -0.031250  0.000000
# 2000-10-24  0.011819 -0.032258 -0.006135

# %%
combnined_stock.columns = ['DJI', 'SNP', 'NIM']
combnined_stock.head()
# Out:
#                  DJI       SNP       NIM
# Date
# 2000-10-18 -0.011366       NaN  0.000000
# 2000-10-19  0.016840 -0.027108 -0.006173
# 2000-10-20  0.008242 -0.009288  0.012422
# 2000-10-23  0.004410 -0.031250  0.000000
# 2000-10-24  0.011819 -0.032258 -0.006135

# %%
combnined_stock.plot(figsize = (20,10))

# %%
# Calculate cumulative returns of all portfolios
combnined_stock_returns = (1+ combnined_stock).cumprod()

# Plot cumulative returns
combnined_stock_returns.plot(figsize = (20,10))

# %%
combnined_stock_returns.plot.density()

# %%
combnined_stock_returns.plot.hist(alpha=0.5)

# %%
# Box plot to visually show risk
combnined_stock_returns.plot(kind = "box", figsize = (5,10))
# Out:
# C:\Users\Dana0\.conda\envs\pyvizenv\lib\site-packages\numpy\core\_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
# Calculate the daily standard deviations of all portfolios
combnined_stock_std = pd.DataFrame(combnined_stock_returns.std()).rename(columns = {0:"std"})
combnined_stock_std
# Out:
#           std
# DJI  0.686208
# SNP  3.219073
# NIM  0.401543
